# %% [markdown]
# ## Linear Regression Assingment
#
# ## Bike Sharing System
#
# #### Problem Statement
# A bike-sharing system is a service in which bikes are made available for shared use to individuals on a short term basis for a price or free. A US bike-sharing provider BoomBikes has recently suffered considerable dips in their revenues due to the ongoing Corona pandemic.
# In such an attempt, BoomBikes aspires to understand the demand for shared bikes among the people after this ongoing quarantine situation ends across the nation due to Covid-19. They have planned this to prepare themselves to cater to the people's needs once the situation gets better all around and stand out from other service providers and make huge profits.
# They want to understand the factors on which the demand for these shared bikes depends. Specifically, they want to understand the factors affecting the demand for these shared bikes in the American market.
# The company wants to know:
# 1. Which variables are significant in predicting the demand for shared bikes.
# 2. How well those variables describe the bike demands

# %% [markdown]
# ### Step 1: Reading and Understanding the Data
# Let us first import NumPy and Pandas and read the day dataset

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

## To build Regression model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import statsmodels.api as sm

# %%
df = pd.read_csv("day.csv")

# %%
# Check the head of the dataset
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# #### There are no null values present in the data

# %% [markdown]
# ### Dropping the columns
# 1. Since year and month columns are there dropping dteday column.
# 2. Dropping the instant column as it is just index.
# 3. Casual and registered columns sum is same as cnt column. Hence dropping those columns.

# %%
df_day = df.drop(['instant','dteday','casual','registered'],axis = 1)

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 68.6 KB

# %%
df_day.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %% [markdown]
# ## Step 2: Visualising the Data
#
# Let us try and understand the data
# - If there is some obvious multicollinearity going on, this is the first place to catch it
# - Here's where you'll also identify if some predictors directly have a strong association with the outcome variable
#
# We'll visualise our data using `matplotlib` and `seaborn`.

# %%
# Creating a list of continuous and categorical columns
continuous_columns = ['temp','atemp','hum','windspeed']
categorical_columns = ['season','yr','mnth','weekday','workingday','weathersit']

# %% [markdown]
# ### Box plot for categorcial variables

# %%
plt.figure(figsize=(15, 12))

plt.subplot(2,3,1)
sns.boxplot(x = 'season', y = 'cnt', data = df_day)
plt.subplot(2,3,2)
sns.boxplot(x = 'yr', y = 'cnt', data = df_day)
plt.subplot(2,3,3)
plt.xticks(rotation = 'vertical')
sns.boxplot(x = 'mnth', y = 'cnt', data = df_day)
plt.subplot(2,3,4)
plt.xticks(rotation = 'vertical')
sns.boxplot(x = 'weekday', y = 'cnt', data = df_day)
plt.subplot(2,3,5)
sns.boxplot(x = 'workingday', y = 'cnt', data = df_day)
plt.subplot(2,3,6)
sns.boxplot(x = 'weathersit', y = 'cnt', data = df_day)
plt.show()

# %% [markdown]
# Based upon the plot above we can infer the below:
# •	Year 2019 has more count.
# •	Seasons summer and fall followed by winter has more counts. In spring season, the count is less.
# •	Months May to October has more count compared to other months.
# •	Working day and weekday doesn’t have much impact on the count.
# •	Clear and misty weather has more count.

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'season', y = 'cnt', hue = 'yr', data = df_day)
plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = 'season', y = 'cnt', hue = 'mnth', data = df_day)
plt.show()

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 68.6 KB

# %% [markdown]
# #### Scatter plot for continuous columns

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.scatterplot(x = 'temp', y = 'cnt', data = df_day)
plt.subplot(2,3,2)
sns.scatterplot(x = 'atemp', y = 'cnt', data = df_day)
plt.subplot(2,3,3)
sns.scatterplot(x = 'hum', y = 'cnt', data = df_day)
plt.subplot(2,3,4)
sns.scatterplot(x = 'windspeed', y = 'cnt', data = df_day)


plt.show()

# %% [markdown]
# temp and atemp seems to have linear correlation

# %%
sns.pairplot(df_day)
plt.show()

# %% [markdown]
# ## Step 3: Data Preparation
#
# ## Creating dummy variables for categorical columns

# %% [markdown]
# #### Change the type of categorical variables to Category to further convert to dummy variables

# %%
df_day['season'] = df_day ['season'].astype('category')
df_day['weathersit'] = df_day ['weathersit'].astype('category')
df_day['weekday'] = df_day ['weekday'].astype('category')
df_day['mnth'] = df_day ['mnth'].astype('category')

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(4)
# memory usage: 49.7 KB

# %%
df_day = pd.get_dummies(df_day,drop_first = True)
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    float64
#  4   atemp         730 non-null    float64
#  5   hum           730 non-null    float64
#  6   windspeed     730 non-null    float64
#  7   cnt           730 non-null    int64
#  8   season_2      730 non-null    bool
#  9   season_3      730 non-null    bool
#  10  season_4      730 non-null    bool
#  11  mnth_2        730 non-null    bool
#  12  mnth_3        730 non-null    bool
#  13  mnth_4        730 non-null    bool
#  14  mnth_5        730 non-null    bool
#  15  mnth_6        730 non-null    bool
#  16  mnth_7        730 non-null    bool
#  17  mnth_8        730 non-null    bool
# ...

# %%
df_day.head()
# Out:
#    yr  holiday  workingday       temp     atemp      hum  windspeed   cnt  \
# 0   0        0           0  14.110847  18.18125  80.5833  10.749882   985
# 1   0        0           0  14.902598  17.68695  69.6087  16.652113   801
# 2   0        0           1   8.050924   9.47025  43.7273  16.636703  1349
# 3   0        0           1   8.200000  10.60610  59.0435  10.739832  1562
# 4   0        0           1   9.305237  11.46350  43.6957  12.522300  1600
#
#    season_2  season_3  ...  mnth_11  mnth_12  weekday_1  weekday_2  weekday_3  \
# 0     False     False  ...    False    False      False      False      False
# 1     False     False  ...    False    False      False      False      False
# 2     False     False  ...    False    False       True      False      False
# 3     False     False  ...    False    False      False       True      False
# 4     False     False  ...    False    False      False      False       True
#
# ...

# %% [markdown]
# ## Step 4: Splitting the Data into Training and Testing Sets
#
# As you know, the first basic step for regression is performing a train-test split.

# %%
np.random.seed(0)
df_train,df_test = train_test_split(df_day,train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
df_train.head()
# Out:
#      yr  holiday  workingday       temp    atemp      hum  windspeed   cnt  \
# 653   1        0           1  19.201653  23.0423  55.8333  12.208807  7534
# 576   1        0           1  29.246653  33.1448  70.4167  11.083475  7216
# 426   1        0           0  16.980847  20.6746  62.1250  10.792293  4066
# 728   1        0           0  10.489153  11.5850  48.3333  23.500518  1796
# 482   1        0           0  15.443347  18.8752  48.9583   8.708325  4220
#
#      season_2  season_3  ...  mnth_11  mnth_12  weekday_1  weekday_2  \
# 653     False     False  ...    False    False      False       True
# 576     False      True  ...    False    False      False       True
# 426     False     False  ...    False    False      False      False
# 728     False     False  ...    False     True      False      False
# 482      True     False  ...    False    False      False      False
#
#      weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  weathersit_3
# ...

# %% [markdown]
# ## Rescaling the features

# %%
scaler = MinMaxScaler()

# %% [markdown]
# ### Applying scaler to columns which are not 0 or 1

# %%
scale_cols = ['temp','atemp','hum','windspeed','cnt']
df_train[scale_cols] = scaler.fit_transform(df_train[scale_cols])

# %%
df_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 653   1        0           1  0.509887  0.501133  0.575354   0.300794
# 576   1        0           1  0.815169  0.766351  0.725633   0.264686
# 426   1        0           0  0.442393  0.438975  0.640189   0.255342
# 728   1        0           0  0.245101  0.200348  0.498067   0.663106
# 482   1        0           0  0.395666  0.391735  0.504508   0.188475
#
#           cnt  season_2  season_3  ...  mnth_11  mnth_12  weekday_1  \
# 653  0.864243     False     False  ...    False    False      False
# 576  0.827658     False      True  ...    False    False      False
# 426  0.465255     False     False  ...    False    False      False
# 728  0.204096     False     False  ...    False     True      False
# 482  0.482973      True     False  ...    False    False      False
#
#      weekday_2  weekday_3  weekday_4  weekday_5  weekday_6  weathersit_2  \
# ...

# %%
# Checking the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ## Dividing X and Y for model building

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %%
X_train.info()

# %% [markdown]
# ## Step 5: Building a linear model
#
# We will be using the LinearRegression function from SciKit Learn for its compatibility with RFE (which is a utility from sklearn)
#
# ### RFE
# Recursive feature elimination

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
# Running RFE with the output number of the variable equal to 10
lm = LinearRegression()
lm.fit(X_train, y_train)

#running RFE
rfe=RFE(lm, n_features_to_select=15)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', False, 9),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_2', True, 1),
#  ('season_3', False, 15),
#  ('season_4', True, 1),
#  ('mnth_2', False, 8),
#  ('mnth_3', True, 1),
#  ('mnth_4', False, 3),
#  ('mnth_5', False, 2),
#  ('mnth_6', False, 4),
#  ('mnth_7', False, 5),
#  ('mnth_8', True, 1),
#  ('mnth_9', True, 1),
#  ('mnth_10', True, 1),
#  ('mnth_11', False, 6),
#  ('mnth_12', False, 7),
#  ('weekday_1', False, 10),
#  ('weekday_2', False, 11),
#  ('weekday_3', False, 13),
#  ('weekday_4', False, 14),
#  ('weekday_5', False, 12),
#  ('weekday_6', True, 1),
#  ('weathersit_2', True, 1),
#  ('weathersit_3', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'season_2',
#        'season_4', 'mnth_3', 'mnth_8', 'mnth_9', 'mnth_10', 'weekday_6',
#        'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['atemp', 'season_3', 'mnth_2', 'mnth_4', 'mnth_5', 'mnth_6', 'mnth_7',
#        'mnth_11', 'mnth_12', 'weekday_1', 'weekday_2', 'weekday_3',
#        'weekday_4', 'weekday_5'],
#       dtype='object')

# %%
X_train_rfe = X_train[col]

# %% [markdown]
# ## Building a linear model through stasmodel api

# %%
print(type(X_train_rfe))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#print(X_train_rfe.dtypes)
print(type(y_train))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#print(X_train_rfe.isnull().sum())
#if type(X_train_rfe) == pd.DataFrame:
#    X_train_rfe = X_train_rfe.values
y_train = y_train.to_numpy()

y_train = y_train.reshape(-1, 1)

# %%
# Adding constant
X_train_lm1 = sm.add_constant(X_train_rfe)
lr1 = sm.OLS(y_train, X_train_lm1.astype(float)).fit()
lr1.params
# Out:
# const           0.189386
# yr              0.228986
# holiday        -0.054303
# workingday      0.043592
# temp            0.535109
# hum            -0.168198
# windspeed      -0.187994
# season_2        0.103994
# season_4        0.138449
# mnth_3          0.021276
# mnth_8          0.057810
# mnth_9          0.126903
# mnth_10         0.040767
# weekday_6       0.052093
# weathersit_2   -0.058295
# weathersit_3   -0.249944
# dtype: float64

# %%
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     185.0
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):          1.47e-191
# Time:                        06:20:38   Log-Likelihood:                 520.35
# No. Observations:                 510   AIC:                            -1009.
# Df Residuals:                     494   BIC:                            -940.9
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.1894      0.029      6.554      0.000       0.133       0.246
# ...

# %%
X_train_rfe.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'season_2',
#        'season_4', 'mnth_3', 'mnth_8', 'mnth_9', 'mnth_10', 'weekday_6',
#        'weathersit_2', 'weathersit_3'],
#       dtype='object')

# %%
# Check for the VIF values of the feature variables.
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X = X_train_rfe

# %%
# Check if exog contains any missing values
print(np.isnan(X).sum().sum())
# Out:
# 0

# %%
# Check if exog contains any infinite values
print(np.isinf(X).sum().sum())
# Out:
# 0

# %%
# Check the data type of X
print(X.dtypes)
# Out:
# yr                int64
# holiday           int64
# workingday        int64
# temp            float64
# hum             float64
# windspeed       float64
# season_2           bool
# season_4           bool
# mnth_3             bool
# mnth_8             bool
# mnth_9             bool
# mnth_10            bool
# weekday_6          bool
# weathersit_2       bool
# weathersit_3       bool
# dtype: object

# %%
# Convert the data type of X to float
X = X.astype(float)

# %%
# Check the data type of X
print(X.dtypes)
# Out:
# yr              float64
# holiday         float64
# workingday      float64
# temp            float64
# hum             float64
# windspeed       float64
# season_2        float64
# season_4        float64
# mnth_3          float64
# mnth_8          float64
# mnth_9          float64
# mnth_10         float64
# weekday_6       float64
# weathersit_2    float64
# weathersit_3    float64
# dtype: object

# %%
# Calculate the VIFs for the new model
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features    VIF
# 4            hum  16.79
# 3           temp  10.17
# 2     workingday   5.09
# 5      windspeed   3.91
# 7       season_4   2.35
# 13  weathersit_2   2.14
# 0             yr   2.03
# 12     weekday_6   1.92
# 6       season_2   1.83
# 11       mnth_10   1.62
# 9         mnth_8   1.61
# 10        mnth_9   1.34
# 8         mnth_3   1.23
# 14  weathersit_3   1.18
# 1        holiday   1.16

# %% [markdown]
# ### Dropping the variable and updating the model
#
# As you can see from the summary and the VIF dataframe, some variables are still insignificant.

# %%
# Dropping highly correlated variables and insignificant variables

X = X.drop('hum', axis=1)

# %%
# Build the model again
X_train_lm = sm.add_constant(X)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

# %%
# Print the summary of the model
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     189.1
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):          2.62e-188
# Time:                        06:23:04   Log-Likelihood:                 509.84
# No. Observations:                 510   AIC:                            -989.7
# Df Residuals:                     495   BIC:                            -926.2
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0897      0.019      4.656      0.000       0.052       0.128
# ...

# %%
# Calculate the VIFs again for the new model

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features   VIF
# 3           temp  6.42
# 2     workingday  4.48
# 4      windspeed  3.71
# 6       season_4  2.07
# 0             yr  2.02
# 5       season_2  1.82
# 11     weekday_6  1.79
# 10       mnth_10  1.62
# 8         mnth_8  1.61
# 12  weathersit_2  1.54
# 9         mnth_9  1.34
# 7         mnth_3  1.21
# 1        holiday  1.12
# 13  weathersit_3  1.10

# %% [markdown]
# ## Dropping the Variable and Updating the Model¶
# As you can notice some of the variable have high VIF values as well as high p-values. Such variables are insignificant and should be dropped.

# %%
# Dropping highly correlated variables and insignificant variables
X = X.drop('mnth_3', axis=1)

# %%
# Build a fitted model
X_train_lm = sm.add_constant(X)

lr_3 = sm.OLS(y_train, X_train_lm).fit()

# %%
# Print the summary of the model

print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.838
# Method:                 Least Squares   F-statistic:                     202.9
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):          6.16e-189
# Time:                        06:23:17   Log-Likelihood:                 508.57
# No. Observations:                 510   AIC:                            -989.1
# Df Residuals:                     496   BIC:                            -929.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0945      0.019      4.961      0.000       0.057       0.132
# ...

# %%
# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features   VIF
# 3           temp  6.38
# 2     workingday  4.39
# 4      windspeed  3.60
# 0             yr  2.02
# 6       season_4  2.02
# 5       season_2  1.82
# 10     weekday_6  1.77
# 9        mnth_10  1.62
# 7         mnth_8  1.59
# 11  weathersit_2  1.54
# 8         mnth_9  1.34
# 1        holiday  1.12
# 12  weathersit_3  1.10

# %%
# Dropping highly correlated variable
X = X.drop('mnth_10', axis=1)

# %%
# Build a fitted model
X_train_lm = sm.add_constant(X)

lr_4 = sm.OLS(y_train, X_train_lm).fit()

# %%
# Print the summary of the model

print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     217.9
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):          3.89e-189
# Time:                        06:29:22   Log-Likelihood:                 506.25
# No. Observations:                 510   AIC:                            -986.5
# Df Residuals:                     497   BIC:                            -931.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const            0.0907      0.019      4.764      0.000       0.053       0.128
# ...

# %%
# Calculate the VIFs again for the new model
vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#         Features   VIF
# 3           temp  6.20
# 2     workingday  4.35
# 4      windspeed  3.60
# 0             yr  2.02
# 5       season_2  1.81
# 9      weekday_6  1.76
# 7         mnth_8  1.58
# 10  weathersit_2  1.54
# 6       season_4  1.53
# 8         mnth_9  1.31
# 1        holiday  1.12
# 11  weathersit_3  1.08

# %% [markdown]
# ## Step 7: Residual Analysis of the train data
#
# So, now to check if the error terms are also normally distributed (which is infact, one of the major assumptions of linear regression), let us plot the histogram of the error terms and see what it looks like.

# %%
y_train_cnt = lr_4.predict(X_train_lm)

# %%
y_train = y_train.ravel()

# %%
y_train_cnt = y_train_cnt.ravel()

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_cnt), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(X.corr(),annot = True, cmap="RdYlGn")
plt.show()

# %%
# Linear relationship validation using CCPR plot
# Component and component plus residual plot

sm.graphics.plot_ccpr(lr_4, 'temp')
plt.show()

sm.graphics.plot_ccpr(lr_4, 'yr')
plt.show()

sm.graphics.plot_ccpr(lr_4, 'windspeed')
plt.show()

sm.graphics.plot_ccpr(lr_4, 'weathersit_3')
plt.show()

# %%
#Homoscedasticity

y_train_pred = lr_4.predict(X_train_lm)
residual = y_train - y_train_pred
sns.scatterplot(x=y_train,y = residual)
plt.plot(y_train,(y_train - y_train), '-r')
plt.xlabel('Count')
plt.ylabel('Residual')
plt.show()

# %% [markdown]
# ## Making Predictions Using the Final Model
#
# Now that we have fitted the model and checked the normality of error terms, it's time to go ahead and make predictions using the final, i.e. fourth model.

# %%
scale_cols = ['temp','atemp','hum','windspeed','cnt']
df_test[scale_cols] = scaler.fit_transform(df_test[scale_cols])

# %%
df_test.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.479452    0.036530    0.698630    0.546312    0.530942    0.508750
# std      0.500722    0.188034    0.459904    0.249189    0.228159    0.201253
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.328479    0.333829    0.358469
# 50%      0.000000    0.000000    1.000000    0.546045    0.547913    0.494200
# 75%      1.000000    0.000000    1.000000    0.759735    0.720622    0.651165
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt
# count  219.000000  219.000000
# mean     0.418870    0.516216
# std      0.188111    0.238702
# min      0.000000    0.000000
# 25%      0.283817    0.359882
# 50%      0.402533    0.520241
# 75%      0.524362    0.682487
# ...

# %%
y_test = df_test.pop('cnt')
X_test = df_test

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X.columns]

# Adding a constant variable
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lr_4.predict(X_test_new)

# %% [markdown]
# ## Step 9: Model Evaluation
#
# Let's now plot the graph for actual versus predicted values.

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)
# Out:
# 0.7879524913006717

# %% [markdown]
# ## The following variables are significant in predicting the demand for shared bikes:
# #### temperature, windspeed, year, season(summer and winter), month(aug, sep), weather situation(misty and light snow)
# #### Holiday, windspeed and misty, light snow are negatively correlated
#
# The equation of linear regression model is :
#
# __cnt = 0.13 + 0.23*yr - 0.097*holiday + 0.52*temp - 0.15*windspeed + 0.1*season2 + 0.14*season_4 + 0.05*mnth_8 + 0.12*mnth_9 -    0.08*weathersit_2 -0.28 * weathersit3__
